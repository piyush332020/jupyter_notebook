# %%
from bs4 import BeautifulSoup

# %%
for i in range(1,51):    
    with open("html/book{i}.html") as f:
        content=f.read()
        soup=BeautifulSoup(content,"html.parser")

# %%
h3=soup.find_all("h3")
print(h3)
# Out:
# [<h3><a href="a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>, <h3><a href="tipping-the-velvet_999/index.html" title="Tipping the Velvet">Tipping the Velvet</a></h3>, <h3><a href="soumission_998/index.html" title="Soumission">Soumission</a></h3>, <h3><a href="sharp-objects_997/index.html" title="Sharp Objects">Sharp Objects</a></h3>, <h3><a href="sapiens-a-brief-history-of-humankind_996/index.html" title="Sapiens: A Brief History of Humankind">Sapiens: A Brief History ...</a></h3>, <h3><a href="the-requiem-red_995/index.html" title="The Requiem Red">The Requiem Red</a></h3>, <h3><a href="the-dirty-little-secrets-of-getting-your-dream-job_994/index.html" title="The Dirty Little Secrets of Getting Your Dream Job">The Dirty Little Secrets ...</a></h3>, <h3><a href="the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html" title="The Coming Woman: A Novel Based on the Life of the Infamous Feminist,
# ...

# %%
articles = soup.select("article.product_pod")
print(len(articles))
# Out:
# 20

# %%
items=[]
for article in articles:
    title=article.find("h3").find("a")["title"]
    price=article.select_one("p.price_color").text.split("Â")[1].replace("£","$ ")
    items.append([title,price,rating])
    rating_element=article.select_one("p.star-rating")
    rating=rating_element["class"][1]
    print(rating)
    # print(items)
# Out:
# Three
# One
# One
# Four
# Five
# One
# Four
# Three
# Four
# One
# Two
# Four
# Five
# Five
# Five
# Three
# One
# One
# Two
# Two

# %%
import pandas as

# %%
pd.DataFrame(items,columns=["books","price","ratings"])
# Out:
#                                                 books    price ratings
# 0                                A Light in the Attic  $ 51.77     Two
# 1                                  Tipping the Velvet  $ 53.74   Three
# 2                                          Soumission  $ 50.10     One
# 3                                       Sharp Objects  $ 47.82     One
# 4               Sapiens: A Brief History of Humankind  $ 54.23    Four
# 5                                     The Requiem Red  $ 22.65    Five
# 6   The Dirty Little Secrets of Getting Your Dream...  $ 33.34     One
# 7   The Coming Woman: A Novel Based on the Life of...  $ 17.93    Four
# 8   The Boys in the Boat: Nine Americans and Their...  $ 22.60   Three
# 9                                     The Black Maria  $ 52.15    Four
# 10     Starving Hearts (Triangular Trade Trilogy, #1)  $ 13.99     One
# 11                              Shakespeare's Sonnets  $ 20.66     Two
# ...

# %%
items=[]
for i in range(1,51):    
    with open(f"html/book{i}.html",encoding="utf-8") as f:
        content=f.read()
        soup=BeautifulSoup(content,"html.parser")
        articles = soup.select("article.product_pod")
        for article in articles:
            title=article.find("h3").find("a")["title"]
            price=article.select_one("p.price_color").text.split("Â")[1].replace("£","$ ")
            items.append([title,price,rating])
            rating_element=article.select_one("p.star-rating")
            rating=rating_element["class"][1]
df=pd.DataFrame(items,columns=["books","price","ratings"])

# %%
df.to_json("books.json", orient="records", indent=4)

# %%
df.to_csv(index=True)
# Out:
# ',books,price,ratings\r\n0,A Light in the Attic,$ 51.77,Five\r\n1,Tipping the Velvet,$ 53.74,Three\r\n2,Soumission,$ 50.10,One\r\n3,Sharp Objects,$ 47.82,One\r\n4,Sapiens: A Brief History of Humankind,$ 54.23,Four\r\n5,The Requiem Red,$ 22.65,Five\r\n6,The Dirty Little Secrets of Getting Your Dream Job,$ 33.34,One\r\n7,"The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull",$ 17.93,Four\r\n8,The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics,$ 22.60,Three\r\n9,The Black Maria,$ 52.15,Four\r\n10,"Starving Hearts (Triangular Trade Trilogy, #1)",$ 13.99,One\r\n11,Shakespeare\'s Sonnets,$ 20.66,Two\r\n12,Set Me Free,$ 17.46,Four\r\n13,Scott Pilgrim\'s Precious Little Life (Scott Pilgrim #1),$ 52.29,Five\r\n14,Rip it Up and Start Again,$ 35.02,Five\r\n15,"Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991",$ 57.25,Five\r\n16,Olio,$ 23.88,Three\r\n17,Mesaerion: The Best Science Fic
# ...

# %%
df.to_xlsx(index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3912\2342360516.py in ?()
# ----> 1 df.to_xlsx(index=True)
#
# D:\anaconda\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to_xlsx'
