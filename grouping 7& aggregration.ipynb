# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "Department": ["HR", "HR", "IT", "IT", "Marketing", "Marketing", "Sales", "Sales"],
    "Team": ["A", "A", "B", "B", "C", "C", "D", "D"],
    "Gender": ["M", "F", "M", "F", "M", "F", "M", "F"],
    "Salary": [85, 90, 78, 85, 92, 88, 75, 80],
    "Age": [23, 25, 30, 22, 28, 26, 21, 27],
    "JoinDate": pd.to_datetime([
        "2020-01-10", "2020-02-15", "2021-03-20", "2021-04-10",
        "2020-05-30", "2020-06-25", "2021-07-15", "2021-08-01"
    ])
})

# %%
df
# Out:
#   Department Team Gender  Salary  Age   JoinDate
# 0         HR    A      M      85   23 2020-01-10
# 1         HR    A      F      90   25 2020-02-15
# 2         IT    B      M      78   30 2021-03-20
# 3         IT    B      F      85   22 2021-04-10
# 4  Marketing    C      M      92   28 2020-05-30
# 5  Marketing    C      F      88   26 2020-06-25
# 6      Sales    D      M      75   21 2021-07-15
# 7      Sales    D      F      80   27 2021-08-01

# %%
df.groupby("Department")['Salary'].mean()
# Out:
# Department
# HR           87.5
# IT           81.5
# Marketing    90.0
# Sales        77.5
# Name: Salary, dtype: float64

# %%
type(df.groupby("Department")['Salary'].mean())
# Out:
# pandas.core.series.Series

# %%
df.groupby("Team")['Salary'].sum()
# Out:
# Team
# A    175
# B    163
# C    180
# D    155
# Name: Salary, dtype: int64

# %%
df.groupby("Team")['Salary'].count()
# Out:
# Team
# A    2
# B    2
# C    2
# D    2
# Name: Salary, dtype: int64

# %%
df.groupby("Team")['Salary'].max()
# Out:
# Team
# A    90
# B    85
# C    92
# D    80
# Name: Salary, dtype: int64

# %%
df.groupby("Department")['Salary'].max()
# Out:
# Department
# HR           90
# IT           85
# Marketing    92
# Sales        80
# Name: Salary, dtype: int64

# %%
df.groupby("Department")['Salary'].count()
# Out:
# Department
# HR           2
# IT           2
# Marketing    2
# Sales        2
# Name: Salary, dtype: int64

# %% [markdown]
# #
#
#
# .agg
#
#
# #

# %%
df.groupby("Department")['Salary'].agg(['mean','max','min'])
# Out:
#             mean  max  min
# Department
# HR          87.5   90   85
# IT          81.5   85   78
# Marketing   90.0   92   88
# Sales       77.5   80   75

# %%
type(df.groupby("Department")['Salary'].agg(['mean','max','min','sum']))
# Out:
# pandas.core.frame.DataFrame

# %%
df['average']=df.groupby('Team')["Salary"].transform("mean")

# %%
df['average2']=df.groupby('Team')["Salary"].mean()

# %%
df
# Out:
#   Department Team Gender  Salary  Age   JoinDate  average  average2
# 0         HR    A      M      85   23 2020-01-10     87.5       NaN
# 1         HR    A      F      90   25 2020-02-15     87.5       NaN
# 2         IT    B      M      78   30 2021-03-20     81.5       NaN
# 3         IT    B      F      85   22 2021-04-10     81.5       NaN
# 4  Marketing    C      M      92   28 2020-05-30     90.0       NaN
# 5  Marketing    C      F      88   26 2020-06-25     90.0       NaN
# 6      Sales    D      M      75   21 2021-07-15     77.5       NaN
# 7      Sales    D      F      80   27 2021-08-01     77.5       NaN
