# %%
def step(x):
    return 1 if x>=0 else 0
def perceptron(x1,x2,w1,w2,b):
    y=x1*w1+x2*w2+b
    return step(y)
print(perceptron(0,0,1,1,-1.5))
print(perceptron(0,1,1,1,-1.5))
print(perceptron(1,0,1,1,-1.5))
print(perceptron(1,1,1,1,-1.5))
# Out:
# 0
# 0
# 0
# 1

# %%
from sklearn.linear_model import Perceptron
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

x,y=make_classification(n_samples=1000,n_features=10,n_classes=2,random_state=42)

x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42)

clf=Perceptron(
    max_iter=1000,
    eta=0.1,
    random_state=42,
    tol=1e-3,
    shuffle=True
)

clf.fit(x_train,y_train)
acurracy=clf.score(x_test,y_test)
print(f"the acurracy is {acurracy}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       5 x,y=make_classification(n_samples=1000,n_features=10,n_classes=2,random_state=42)
#       7 x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42)
# ----> 9 clf=Perceptron(
#      10     max_iter=1000,
#      11     eta=0.1,
#      12     random_state=42,
#      13     tol=1e-3,
#      14     shuffle=True
#      15 )
#      17 clf.fit(x_train,y_train)
#      18 acurracy=clf.score(x_test,y_test)
#
# TypeError: Perceptron.__init__() got an unexpected keyword argument 'eta'. Did you mean 'eta0'?
