# %%
import matplotlib.pyplot as plt

# %%
years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]
sehwag = [0, 300, 800, 1200, 1500, 1700, 1600, 1400, 1000, 0]


plt.bar(years,runs)
plt.plot(years,kohli ,label='kholi' ,color="green" ,linestyle='-.')
plt.plot(years,sehwag ,label='kholi' ,color="green" ,linestyle='--')
plt.xlabel("year")
plt.ylabel("runs")
plt.legend()
plt.style.use('fivethirtyeight')
plt.grid(True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       2 kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]
#       3 sehwag = [0, 300, 800, 1200, 1500, 1700, 1600, 1400, 1000, 0]
# ----> 6 plt.bar(years,run)
#       7 plt.plot(years,kohli ,label='kholi' ,color="green" ,linestyle='-.')
#       8 plt.plot(years,sehwag ,label='kholi' ,color="green" ,linestyle='--')
#
# NameError: name 'run' is not defined
