# %%
import matplotlib.pyplot as plt

# %%
plt.style.use("ggplot")

# %%
import matplotlib.pyplot as plt

explode=[0.2,0.4,0,0]  #alag kardeta h

labels = ["Sachin", "Sehwag", "Kohli", "Yuvraj"]
runs = [18000, 8000, 12000, 9500]
plt.title("Career Runs of Indian Batsmen")
plt.pie(runs, labels=labels, explode=explode ,autopct="%1.1f%%",wedgeprops={'edgecolor': "black",
                                                                            'linewidth':"3",
                                                                            'linestyle':"-.",
                                                                            'fill':True,})
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 8
#       6 runs = [18000, 8000, 12000, 9500]
#       7 plt.title("Career Runs of Indian Batsmen")
# ----> 8 plt.pie(runs, labels=labels, explode=explode ,autopct="%1.1f%%",wedgeprops={'edgecolor': "black",'linewidth':"3",'linestyle':"-.",'fill':True,'shadow':True})
#       9 plt.show()
#
# File D:\anaconda\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File D:\anaconda\Lib\site-packages\matplotlib\pyplot.py:3806, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3783 @_copy_docstring_and_deprecators(Axes.pie)
#    3784 def pie(
#    3785     x: ArrayLike,
#    (...)   3804     data=None,
#    3805 ) -> tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]:
# -> 3806     return gca().pie(
#    3807         x,
#    3808         explode=explode,
#    3809         labels=labels,
#    3810         colors=colors,
#    3811         autopct=autopct,
#    3812         pctdistance=pctdistance,
#    3813         shadow=shadow,
#    3814         labeldistance=labeldistance,
#    3815         startangle=startangle,
#    3816         radius=radius,
#    3817         counterclock=counterclock,
#    3818         wedgeprops=wedgeprops,
#    3819         textprops=textprops,
#    3820         center=center,
#    3821         frame=frame,
#    3822         rotatelabels=rotatelabels,
#    3823         normalize=normalize,
#    3824         hatch=hatch,
#    3825         **({"data": data} if data is not None else {}),
#    3826     )
#
# File D:\anaconda\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File D:\anaconda\Lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File D:\anaconda\Lib\site-packages\matplotlib\axes\_axes.py:3418, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch)
#    3410 y += expl * math.sin(thetam)
#    3412 w = mpatches.Wedge((x, y), radius, 360. * min(theta1, theta2),
#    3413                    360. * max(theta1, theta2),
#    3414                    facecolor=get_next_color(),
#    3415                    hatch=next(hatch_cycle),
#    3416                    clip_on=False,
#    3417                    label=label)
# -> 3418 w.set(**wedgeprops)
#    3419 slices.append(w)
#    3420 self.add_patch(w)
#
# File D:\anaconda\Lib\site-packages\matplotlib\artist.py:146, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     138 if not hasattr(cls.set, '_autogenerated_signature'):
#     139     # Don't overwrite cls.set if the subclass or one of its parents
#     140     # has defined a set method set itself.
#     141     # If there was no explicit definition, cls.set is inherited from
#     142     # the hierarchy of auto-generated set methods, which hold the
#     143     # flag _autogenerated_signature.
#     144     return
# --> 146 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     147 cls.set.__name__ = "set"
#     148 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File D:\anaconda\Lib\site-packages\matplotlib\artist.py:1241, in Artist.set(self, **kwargs)
#    1237 def set(self, **kwargs):
#    1238     # docstring and signature are auto-generated via
#    1239     # Artist._update_set_signature_and_docstring() at the end of the
#    1240     # module.
# -> 1241     return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#
# File D:\anaconda\Lib\site-packages\matplotlib\artist.py:1233, in Artist._internal_update(self, kwargs)
#    1226 def _internal_update(self, kwargs):
#    1227     """
#    1228     Update artist properties without prenormalizing them, but generating
#    1229     errors as if calling `set`.
#    1230
#    1231     The lack of prenormalization is to maintain backcompatibility.
#    1232     """
# -> 1233     return self._update_props(
#    1234         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1235         "{prop_name!r}")
#
# File D:\anaconda\Lib\site-packages\matplotlib\artist.py:1206, in Artist._update_props(self, props, errfmt)
#    1204             func = getattr(self, f"set_{k}", None)
#    1205             if not callable(func):
# -> 1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
#    1209             ret.append(func(v))
#    1210 if ret:
#
# AttributeError: Wedge.set() got an unexpected keyword argument 'shadow'
