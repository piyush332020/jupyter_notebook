# %%
import matplotlib.pyplot as plt

# %%
plt.style.use("ggplot")

# %%
import matplotlib.pyplot as plt

labels = ["Sachin", "Sehwag", "Kohli", "Yuvraj"]
runs = [18000, 8000, 12000, 9500]

plt.title("Career Runs of Indian Batsmen")
plt.pie(runs, labels=labels, autopct="%1.1f%%",wedgeprop={'edgecolor': "black",'linewidth':"3",'linestyle':"_."})
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       4 runs = [18000, 8000, 12000, 9500]
#       6 plt.title("Career Runs of Indian Batsmen")
# ----> 7 plt.pie(runs, labels=labels, autopct="%1.1f%%",wedgeprop={'edgecolor': "black",'linewidth':"3",'linestyle':"_."})
#       8 plt.show()
#
# File D:\anaconda\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# TypeError: pie() got an unexpected keyword argument 'wedgeprop'. Did you mean 'wedgeprops'?
