# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3],[4,5,6])

# %%
plt.show()

# %%
plt.plot([1,2,3],[4,5,6])
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("this is the graph")
# Out:
# Text(0.5, 1.0, 'this is the graph')

# %%
years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]
sehwag = [0, 300, 800, 1200, 1500, 1700, 1600, 1400, 1000, 0]

plt.plot(years, kohli, label="Virat Kohli")
plt.plot(years, sehwag, label="Virender Sehwag")

plt.xlabel("Year")
plt.ylabel("Runs Scored")
plt.title("Performance Comparison")
plt.legend()
plt.show()

# %%
#format=[marker][line][color] ex-o->circled with o  && ' -- ' ->dotted line  && r->red

plt.plot(years, kohli, 'o--r', label="Kohli")  # red circles with dashed lines
plt.plot(years, sehwag, ':^g', label="Sehwag")  # green triangles dotted
plt.legend()

# %%
plt.plot(years, kohli, color='orange', linestyle='--', linewidth=5 ,label="Kohli")
plt.plot(years, sehwag, color='green', linestyle='-.', label="Sehwag")
plt.plot(years, runs, color='blue', label="Tendulkar")
plt.grid(True)
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 plt.plot(years, kohli, color='orange', linestyle='--', linewidth=5 ,label="Kohli")
#       2 plt.plot(years, sehwag, color='green', linestyle='-.', label="Sehwag")
# ----> 3 plt.plot(years, runs, color='blue', label="Tendulkar")
#       4 plt.grid(True)
#       5 plt.legend()
#
# NameError: name 'runs' is not defined

# %%
plt.style.available

# %%
plt.style.use('seaborn-v0_8-muted')
plt.plot(years, kohli, color='orange', linestyle='--', linewidth=5 ,label="Kohli")
plt.plot(years, sehwag, color='green', linestyle='-.', label="Sehwag")
plt.plot(years, runs, color='blue', label="Tendulkar")
plt.grid(True)
plt.legend()

# %%
with plt.xkcd():
    plt.plot(years, kohli, color='orange', linestyle='--', linewidth=5 ,label="Kohli")
    plt.plot(years, sehwag, color='green', linestyle='-.', label="Sehwag")
    plt.plot(years, runs, color='blue', label="Tendulkar")
    plt.grid(True)
    plt.legend()

# %%
years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]
sehwag = [0, 300, 800, 1200, 1500, 1700, 1600, 1400, 1000, 0]

plt.plot(years,kohli ,label='kholi' ,color="green" ,linestyle='-.')
plt.plot(years,sehwag ,label='kholi' ,color="green" ,linestyle='--')
plt.xlabel("year")
plt.ylabel("runs")
plt.legend()
plt.style.use('fivethirtyeight')
plt.grid(True)
