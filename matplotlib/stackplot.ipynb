# %%
import matplotlib.pyplot as plt

# %%
activities=['studying' , 'playing','watching' ,'sleeping']
time=[3,2,2,5]
colors={'blue','red','yellow','pink'}

# %%
plt.figure(figsize=(6,6))
plt.pie(time,labels=activities,colors=colors,autopct='%1.1f%%')
plt.title('schhol student')
plt.axis(equal')
# Out:
# ([<matplotlib.patches.Wedge at 0x1cd5d340980>,
# ...
#  [Text(0.777817442305461, 0.7778174763049434, 'studying'),
#   Text(-0.5500000555209211, 0.9526279121078616, 'playing'),
#   Text(-1.0999999999999959, -9.616505800409723e-08, 'watching'),
#   Text(0.2847014133410698, -1.062518284662244, 'sleeping')],
#  [Text(0.4242640594393423, 0.4242640779845145, '25.0%'),
#   Text(-0.3000000302841388, 0.5196152247861062, '16.7%'),
#   Text(-0.5999999999999978, -5.2453668002234845e-08, '16.7%'),
#   Text(0.1552916800042199, -0.5795554279975875, '41.7%')])
