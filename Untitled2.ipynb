# %%
name="shreya"

# %%
name.upper()
# Out:
# 'SHREYA'

# %%
name.endswith('ya')
# Out:
# True

# %%
name.isdigit()
# Out:
# False

# %%
name.count(name)
# Out:
# 1

# %%
len(name)
# Out:
# 6

# %%
name.strip()
# Out:
# 'shreya'

# %%
name[1:-1]
# Out:
# 'hrey'

# %%
name[::-1]
# Out:
# 'ayerhs'

# %%
s={4,5,67,4}

# %%
s
# Out:
# {4, 5, 67}

# %%
s.update({4,64,34})

# %%
s
# Out:
# {4, 5, 34, 64, 67}

# %%
s.remove(4)

# %%
s
# Out:
# {5, 34, 64, 67}

# %%
s.pop()
# Out:
# 64

# %%
s
# Out:
# {5, 34, 67}

# %%
s.pop()
# Out:
# 34

# %%
s.update({79})

# %%
s
# Out:
# {5, 67, 79}

# %%
s.pop()
# Out:
# 67

# %%
p={1,2,5,2,3}

# %%
s.issubset(p)
# Out:
# False

# %%
s.issuperset(p)
# Out:
# False

# %%
import json

# %%
obj={"name":"piyush","age":23,"salary":120000}

# %%
file=open("data.json","w")

# %%
json.dump(obj,file)

# %%
file.close()

# %%
json.dumps(obj)
# Out:
# '{"name": "piyush", "age": 23, "salary": 120000}'
