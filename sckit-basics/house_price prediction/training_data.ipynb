# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

# %%
df=pd.read_csv("house_price_data.csv",encoding="utf-8")

# %%
df.drop(columns='ID')
# Out:
#               State       City      Locality      Property_Type  BHK  \
# 0        Tamil Nadu    Chennai   Locality_84          Apartment    1
# 1       Maharashtra       Pune  Locality_490  Independent House    3
# 2            Punjab   Ludhiana  Locality_167          Apartment    2
# 3         Rajasthan    Jodhpur  Locality_393  Independent House    2
# 4         Rajasthan     Jaipur  Locality_466              Villa    4
# ...             ...        ...           ...                ...  ...
# 249995      Gujarat  Ahmedabad  Locality_187  Independent House    5
# 249996   Tamil Nadu    Chennai  Locality_348          Apartment    1
# 249997    Telangana   Warangal  Locality_225              Villa    4
# 249998       Odisha    Cuttack  Locality_138              Villa    1
# 249999      Haryana    Gurgaon  Locality_268  Independent House    3
#
#         Size_in_SqFt  Price_in_Lakhs  Price_per_SqFt  Year_Built  \
# 0               4740          489.76            0.10        1990
# ...

# %%
x = df.iloc[:, list(range(0, 5)) + list(range(7, 19))]
y=df.iloc[:,5]

# %%
y.values
# Out:
# array([1, 3, 2, ..., 4, 1, 3], shape=(250000,))

# %%
x.values
# Out:
# array([[1, 'Tamil Nadu', 'Chennai', ..., 'High', 'No', 'No'],
#        [2, 'Maharashtra', 'Pune', ..., 'Low', 'No', 'Yes'],
#        [3, 'Punjab', 'Ludhiana', ..., 'Low', 'Yes', 'No'],
#        ...,
#        [249998, 'Telangana', 'Warangal', ..., 'High', 'Yes', 'Yes'],
#        [249999, 'Odisha', 'Cuttack', ..., 'Low', 'Yes', 'Yes'],
#        [250000, 'Haryana', 'Gurgaon', ..., 'Medium', 'No', 'No']],
#       shape=(250000, 17), dtype=object)

# %%
model=RandomForestClassifier()

# %%
print(x.dtypes)
# Out:
# ID                                  int64
# State                              object
# City                               object
# Locality                           object
# Property_Type                      object
# Price_in_Lakhs                    float64
# Price_per_SqFt                    float64
# Year_Built                          int64
# Furnished_Status                   object
# Floor_No                            int64
# Total_Floors                        int64
# Age_of_Property                     int64
# Nearby_Schools                      int64
# Nearby_Hospitals                    int64
# Public_Transport_Accessibility     object
# Parking_Space                      object
# Security                           object
# dtype: object

# %%
model.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25716\1265173374.py in ?()
# ----> 1 model.fit(x,y)
#
# D:\anaconda\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1361                 skip_parameter_validation=(
#    1362                     prefer_skip_nested_validation or global_skip_validation
#    1363                 )
#    1364             ):
# -> 1365                 return fit_method(estimator, *args, **kwargs)
#
# D:\anaconda\Lib\site-packages\sklearn\ensemble\_forest.py in ?(self, X, y, sample_weight)
#     355         # Validate or convert input data
#     356         if issparse(y):
#     357             raise ValueError("sparse multilabel-indicator for y is not supported.")
#     358
# --> 359         X, y = validate_data(
#     360             self,
#     361             X,
#     362             y,
#
# ...
