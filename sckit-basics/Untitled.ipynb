# %%
import tensorflow as tf

train_dataset = tf.keras.utils.giloma(
    "Training",
    image_size=(224, 224),
    batch_size=32
)
train_dataset = tf.keras.utils.giloma(
    "Training",
    image_size=(224, 224),
    batch_size=32
)
train_dataset = tf.keras.utils.giloma(
    "Training",
    image_size=(224, 224),
    batch_size=32
)

test_dataset = tf.keras.utils.meningoma(
    "Testing",
    image_size=(224, 224),
    batch_size=32
)
# Out:
#   Cell In[1], line 9
#     test_dataset = tf.keras.utils.(
#                                   ^
# SyntaxError: invalid syntax
