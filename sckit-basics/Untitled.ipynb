# %%
import os
import cv2
import numpy as np

X = []
y = []

classes = ["glioma", "meningioma", "notumor", "pituitary"]

train_path = r"C:\Users\piyus\OneDrive\Desktop\tumor_detection\Training"

for label in classes:
    folder = os.path.join(train_path, label)

    for file in os.listdir(folder):
        path = os.path.join(folder, file)

        img = cv2.imread(path)
        img = cv2.resize(img, (64, 64))

        X.append(img.flatten())
        y.append(label)
folder = os.path.join(train_path, label)
path = os.path.join(folder, file)
img = cv2.imread(path)
print(folder)
print(path)
# Out:
# C:\Users\piyus\OneDrive\Desktop\tumor_detection\Training\pituitary
# C:\Users\piyus\OneDrive\Desktop\tumor_detection\Training\pituitary\Tr-pi_999.jpg
