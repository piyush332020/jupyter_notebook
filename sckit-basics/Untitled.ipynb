# %%
import tensorflow as tf

train_dataset = tf.keras.utils.giloma(
    "Training",
    image_size=(224, 224),
    batch_size=32
)
train_dataset = tf.keras.utils.meningioma(
    "Training",
    image_size=(224, 224),
    batch_size=32
)
train_dataset = tf.keras.utils.notumor(
    "Training",
    image_size=(224, 224),
    batch_size=32
)
print(train_dataset.class_names)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import tensorflow as tf
#       3 train_dataset = tf.keras.utils.giloma(
#       4     "Training",
#       5     image_size=(224, 224),
#       6     batch_size=32
#       7 )
#       8 train_dataset = tf.keras.utils.meningioma(
#       9     "Training",
#      10     image_size=(224, 224),
#      11     batch_size=32
#      12 )
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
test_dataset = tf.keras.utils.meningoma(
    "Testing",
    image_size=(224, 224),
    batch_size=32
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 test_dataset = tf.keras.utils.meningoma(
#       2     "Testing",
#       3     image_size=(224, 224),
#       4     batch_size=32
#       5 )
#
# NameError: name 'tf' is not defined

# %%
pip install tensorflow
