# %%
from sklearn.tree import DecisionTreeClassifier

# %%
features=[
    [150,0],
    [170,0],
    [130,1],
    [120,1]
]
labels=["apple","apple","orange","orange"]

# %%
clf=DecisionTreeClassifier()

# %%
clf=clf.fit(features,labels)

# %%
prediction=clf.predict([[150,1],[134,1],[34,0]])

# %%
for i in range(prediction.size):
    print(f"the fruit is-> {prediction[i]}")
# Out:
# the fruit is-> apple
# the fruit is-> orange
# the fruit is-> orange

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(11,0))

# %%
plot_tree(clf,feature_names=["weight","color"],class_name=["apple","orange"],filled=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 plot_tree(clf,feature_names=["weight","color"],class_name=["apple","orange"],filled=True)
#
# File D:\anaconda\Lib\site-packages\sklearn\utils\_param_validation.py:196, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
# --> 196 params = func_sig.bind(*args, **kwargs)
#     197 params.apply_defaults()
#     199 # ignore self/cls and positional/keyword markers
#
# File D:\anaconda\Lib\inspect.py:3304, in Signature.bind(self, *args, **kwargs)
#    3299 def bind(self, /, *args, **kwargs):
#    3300     """Get a BoundArguments object, that maps the passed `args`
#    3301     and `kwargs` to the function's signature.  Raises `TypeError`
#    3302     if the passed arguments can not be bound.
#    3303     """
# -> 3304     return self._bind(args, kwargs)
#
# File D:\anaconda\Lib\inspect.py:3293, in Signature._bind(self, args, kwargs, partial)
#    3283         raise TypeError(
#    3284             'got some positional-only arguments passed as '
#    3285             'keyword arguments: {arg!r}'.format(
#    (...)   3290             ),
#    3291         )
#    3292     else:
# -> 3293         raise TypeError(
#    3294             'got an unexpected keyword argument {arg!r}'.format(
#    3295                 arg=next(iter(kwargs))))
#    3297 return self._bound_arguments_cls(self, arguments)
#
# TypeError: got an unexpected keyword argument 'class_name'
