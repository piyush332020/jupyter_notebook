# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

# %%
df=pd.read_excel("iris-train.xlsx")

# %%
df.head()
# Out:
#    sepallength  sepalwidth  petallength  petalwidth           class
# 0          7.9         3.8          6.4         2.0  Iris-virginica
# 1          7.7         3.8          6.7         2.2  Iris-virginica
# 2          7.7         3.0          6.1         2.3  Iris-virginica
# 3          7.7         2.8          6.7         2.0  Iris-virginica
# 4          7.7         2.6          6.9         2.3  Iris-virginica

# %%
x=df.iloc[:,:-1]

# %%
x
# Out:
#      sepallength  sepalwidth  petallength  petalwidth
# 0            7.9         3.8          6.4         2.0
# 1            7.7         3.8          6.7         2.2
# 2            7.7         3.0          6.1         2.3
# 3            7.7         2.8          6.7         2.0
# 4            7.7         2.6          6.9         2.3
# ..           ...         ...          ...         ...
# 111          4.5         2.3          1.3         0.3
# 112          4.4         3.2          1.3         0.2
# 113          4.4         3.0          1.3         0.2
# 114          4.4         2.9          1.4         0.2
# 115          4.3         3.0          1.1         0.1
#
# [116 rows x 4 columns]

# %%
y=df.iloc[:,-1]

# %%
y
# Out:
# 0      Iris-virginica
# 1      Iris-virginica
# 2      Iris-virginica
# 3      Iris-virginica
# 4      Iris-virginica
#             ...
# 111       Iris-setosa
# 112       Iris-setosa
# 113       Iris-setosa
# 114       Iris-setosa
# 115       Iris-setosa
# Name: class, Length: 116, dtype: object

# %%
model=RandomForestClassifier()

# %%
model.fit(x,y)
# Out:
# RandomForestClassifier()

# %%
pedicion=model.predict([[5.43,4.5,1.5]])
# Out:
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 pedicion=model.predict([[5.43,4.5,1.5]])
#
# File D:\anaconda\Lib\site-packages\sklearn\ensemble\_forest.py:903, in ForestClassifier.predict(self, X)
#     882 def predict(self, X):
#     883     """
#     884     Predict class for X.
#     885
#    (...)    901         The predicted classes.
#     902     """
# --> 903     proba = self.predict_proba(X)
#     905     if self.n_outputs_ == 1:
#     906         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File D:\anaconda\Lib\site-packages\sklearn\ensemble\_forest.py:945, in ForestClassifier.predict_proba(self, X)
#     943 check_is_fitted(self)
# ...
