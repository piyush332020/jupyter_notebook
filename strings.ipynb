# %%
a=5

# %%
b=32

# %%
a+b
# Out:
# 37

# %%
name="harry" #this will print harry

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
type(name)
# Out:
# str

# %%
a="4566"

# %%
b="5677"

# %%
a+b
# Out:
# '45665677'

# %%
print(a+b)
# Out:
# 45665677
