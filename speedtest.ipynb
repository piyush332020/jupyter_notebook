# %%
import numpy as np
import time

size=1_000_000
l1=list(range(size))
l2=list(range(size))
start=time.time()
add=[x+y for x,y in zip(l1,l2)]
end=time.time()
print(end-start)
# Out:
# 0.15639305114746094

# %%
l1=[1,2,4]

# %%
l2=[6,7,8]

# %%
list(zip(l1,l2))
# Out:
# [(1, 6), (2, 7), (4, 8)]

# %%
#using numpy arrays

import numpy as np
import time

size=1_000_000
l1=np.array(list(range(size)))
l2=np.array(list(range(size)))
start=time.time()
add=[l1+l2]
end=time.time()
print(end-start)
# Out:
# 0.04688405990600586

# %%
np.array([1,2,3,4,5])
# Out:
# array(['1', '2', '3', '4', '5', 'piyush'], dtype='<U21')

# %%
arr=np.array([[1,2,3],[4,5,6]])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
arr.shape
# Out:
# (2, 3)

# %%
import sys
list_data=list(range(100000))
numpy_data=np.array(list_data)
print("python list size:",sys.getsizeof(list_data)*len(list_data),"bytes")
print("numpy list size:", numpy_data.nbytes, "bytes")
# Out:
# python list size: 80005600000 bytes
# numpy list size: 800000 bytes

# %%
list_data=[2,3,4,5]
numpy_data=np.array(list_data)
start=time.time()
list_ans=[x**2 for x in list_data]
end=time.time()
print("python",end-start)
start=time.time()
numpy_ans=numpy_data**2
end=time.time()
print("numpy",end-start)
# Out:
# python 9.965896606445312e-05
# numpy 0.0001704692840576172
